# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from numpy.random import randn, randint, uniform, sample

# %%
randn(1000)
# Out:
# array([-5.55174676e-01, -9.69024472e-01, -4.31063510e-01, -3.32634520e-01,
#         9.59886466e-01, -3.72000305e-01, -7.32725126e-01,  1.29296053e+00,
#         7.54638782e-01, -2.19079942e+00,  7.70262679e-01, -3.88236109e-01,
#         1.25360789e+00,  1.97506852e-01,  6.18229819e-01, -7.75649386e-01,
#         1.38779929e-02,  8.91265199e-01,  4.71506395e-01,  4.56422022e-01,
#         4.91745431e-01, -1.63181965e+00,  6.35672162e-01, -9.67414917e-01,
#        -1.07086726e+00, -7.01733934e-02, -7.71308034e-01,  6.62495452e-01,
#         7.37725290e-01, -1.24308624e+00,  5.66356827e-01,  5.75015716e-01,
#         9.81825757e-01, -1.39356404e+00, -1.46464177e+00, -2.36406269e-01,
#         7.26589027e-01, -6.04042001e-01, -1.56678906e-01, -7.89775607e-01,
#        -6.30290502e-01,  2.11432321e-01,  6.80223602e-01,  9.72862485e-01,
#        -1.38113202e+00, -4.00107858e-01, -5.05127193e-01, -4.99438846e-01,
# ...

# %%
df=pd.DataFrame(randn(1000),index=pd.date_range('2018-07-06',periods=1000),columns=['values'])
df.head(15)
# Out:
#               values
# 2018-07-06  0.806839
# 2018-07-07 -0.673687
# 2018-07-08 -0.188648
# 2018-07-09  2.292755
# 2018-07-10  0.312151
# 2018-07-11  0.012090
# 2018-07-12 -0.088093
# 2018-07-13  0.744112
# 2018-07-14 -1.267389
# 2018-07-15  0.661091
# 2018-07-16 -0.458898
# 2018-07-17 -1.035545
# 2018-07-18  1.090029
# 2018-07-19 -0.711316
# 2018-07-20 -1.095686

# %%
ts=pd.Series(randn(1000),index=pd.date_range('2018-07-06',periods=1000))
ts.head()
# Out:
# 2018-07-06   -0.319544
# 2018-07-07   -1.072984
# 2018-07-08    0.913636
# 2018-07-09    0.081500
# 2018-07-10   -1.770151
# Freq: D, dtype: float64

# %%
ts.plot(use_index=(0,True))

# %%
ts.plot(figsize=(6,5))

# %%
ts=ts.cumsum()                            #cumulatative sum
ts.head()
# Out:
# 2018-07-06   -0.319544
# 2018-07-07   -1.392528
# 2018-07-08   -0.478892
# 2018-07-09   -0.397392
# 2018-07-10   -2.167542
# Freq: D, dtype: float64

# %%
ts.plot(figsize=(6,5))                         #using pandas

# %%
plt.plot(ts)                            #using matplotlib

# %%
df = pd.DataFrame(randn(1000), index = pd.date_range('2019-06-07', periods = 1000), columns=['value'])
ts = pd.Series(randn(1000), index = pd.date_range('2019-06-07', periods = 1000))
df.head()
# Out:
#                value
# 2019-06-07  1.232051
# 2019-06-08 -0.261482
# 2019-06-09  1.242395
# 2019-06-10  0.895954
# 2019-06-11  0.736072

# %%
df['value'] = df['value'].cumsum()
df.head()
# Out:
#                 value
# 2019-06-07   1.232051
# 2019-06-08   2.202620
# 2019-06-09   4.415583
# 2019-06-10   7.524501
# 2019-06-11  11.369490

# %%
ts = ts.cumsum()
ts.head()
# Out:
# 2019-06-07   -0.173462
# 2019-06-08   -1.410669
# 2019-06-09   -1.760961
# 2019-06-10   -1.244528
# 2019-06-11   -0.363838
# Freq: D, dtype: float64

# %%
type(df), type(ts)
# Out:
# (pandas.core.frame.DataFrame, pandas.core.series.Series)

# %%
ts.plot(figsize=(5,5))

# %%
plt.plot(ts)

# %%
df.plot()

# %%
iris = sns.load_dataset('iris')                      #inbuilt database of seaborn (4 feAtures & 1 label)
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
ax = iris.plot(figsize=(15,8), title='Iris Dataset')
#ax.set_xlabel('X Axis')
#ax.set_ylabel('Y Axis')

# %%
ts.plot()

# %%
ts.plot(kind='density')

# %%
ts.plot(kind = 'bar')

# %%
df = iris.drop(['species'], axis = 1)

# %%
df.iloc[0]
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
df.iloc[0].plot(kind='bar')

# %%
df.iloc[0].plot.bar()

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic['pclass'].plot(kind = 'line')

# %%
df = pd.DataFrame(randn(10, 4), columns=['a', 'b', 'c', 'd'])
df.head(10)
# Out:
#           a         b         c         d
# 0 -0.084207 -1.825076 -0.602877 -0.268684
# 1 -1.119940  0.148428 -0.782825 -1.448724
# 2  0.236500 -2.294824  1.458785 -0.590749
# 3  2.317237  0.586727 -1.611766  1.270970
# 4  0.328998 -0.892969 -0.750124  1.155410
# 5 -1.157343 -0.740719 -0.076176  0.583553
# 6  0.430920  1.575799 -0.915291  1.534720
# 7  0.236740  1.021043  1.756547 -1.180897
# 8 -1.601271 -0.633892 -0.306024  0.701243
# 9 -1.219346 -0.371577 -1.750825 -0.587641

# %%
df.plot.bar()

# %%
df.plot(kind = 'hist')

# %%
df.plot.barh()

# %%
iris.plot.hist()

# %%
iris.plot(kind = 'hist')

# %%
iris.plot(kind = 'hist', stacked = False, bins = 1000)                      #bins = width of the graphs

# %%
iris.plot(kind = 'hist', stacked = False, bins = 10)

# %%
iris.plot(kind = 'hist', stacked = True, bins = 50, orientation = 'horizontal')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris['sepal_width'].mean()
# Out:
# 3.057333333333334

# %%
iris['sepal_width'].diff()
# Out:
# 0      NaN
# 1     -0.5
# 2      0.2
# 3     -0.1
# 4      0.5
#       ...
# 145   -0.3
# 146   -0.5
# 147    0.5
# 148    0.4
# 149   -0.4
# Name: sepal_width, Length: 150, dtype: float64

# %%
iris['sepal_width'].diff().plot(kind = 'hist', stacked = True, bins = 50)

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic['fare'].diff()
# Out:
# 0          NaN
# 1      64.0333
# 2     -63.3583
# 3      45.1750
# 4     -45.0500
#         ...
# 886   -16.1250
# 887    17.0000
# 888    -6.5500
# 889     6.5500
# 890   -22.2500
# Name: fare, Length: 891, dtype: float64

# %%
titanic['fare'].diff().plot(figsize=(10,5),title='Fare')

# %%
titanic['survived'].plot.hist()

# %%
df.diff().hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000023EF51ED208>,
# ...
#       dtype=object)

# %%
df = iris.drop(['species'], axis = 1)
df.diff().head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           NaN          NaN           NaN          NaN
# 1          -0.2         -0.5           0.0          0.0
# 2          -0.2          0.2          -0.1          0.0
# 3          -0.1         -0.1           0.2          0.0
# 4           0.4          0.5          -0.1          0.0

# %%
df.diff().hist(color = 'b', alpha = 0.1, figsize=(10,10))                    #alpha = intensity of colour, colour=HTML
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a2dcbceb8>,
# ...
#       dtype=object)

# %%
color = {'boxes': 'DarkGreen', 'whiskers': 'b'}
color
# Out:
# {'boxes': 'DarkGreen', 'whiskers': 'b'}

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length')

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length', c = 'sepal_width')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length', label = 'Length');
#df.plot.scatter(x = 'sepal_width', y = 'petal_width', label = 'Width', ax = ax, color = 'r')
#df.plot.scatter(x = 'sepal_width', y = 'petal_length', label = 'Width', ax = ax, color = 'g')

# %%
#s=increase the size of each bubble

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length', c = 'sepal_width', s = 190)

# %%
df.plot.hexbin(x = 'sepal_length', y = 'petal_length', gridsize = 5, C = 'sepal_width')

# %%
d = df.iloc[0]
d
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
d.plot.pie(figsize = (10,10))

# %%
d = df.head(3).T

# %%
d
# Out:
#                 0    1    2
# sepal_length  5.1  4.9  4.7
# sepal_width   3.5  3.0  3.2
# petal_length  1.4  1.4  1.3
# petal_width   0.2  0.2  0.2

# %%
d.plot.pie(subplots = True, figsize = (20, 20))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x1a2f7d3f28>,
# ...
#       dtype=object)

# %%
d.plot.pie(subplots = True, figsize = (20, 20), fontsize = 26, autopct = '%.2f')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x1a303d2630>,
# ...
#       dtype=object)

# %%
[0.1]*4
# Out:
# [0.1, 0.1, 0.1, 0.1]

# %%
series = pd.Series([0.2]*5, index = ['a','b','c', 'd','e'], name = 'Pie Plot')
series.plot.pie()

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(df, figsize= (8,8), diagonal='kde', color = 'b')
plt.show()

# %%
ts.plot.kde()

# %%
from pandas.plotting import andrews_curves

# %%
andrews_curves(df, 'sepal_width')

# %%
ts.plot(style = 'r*', label = 'Series', legend = True)

# %%
ts.plot(style = 'r--', label = 'Series', legend = True)

# %%
df.plot(legend = True, figsize = (10, 5), logy = True)

# %%
df.head(0)
# Out:
# Empty DataFrame
# Columns: [sepal_length, sepal_width, petal_length, petal_width]
# Index: []

# %%
x = df.drop(['sepal_width', 'petal_width'], axis = 1)
x.head()
# Out:
#    sepal_length  petal_length
# 0           5.1           1.4
# 1           4.9           1.4
# 2           4.7           1.3
# 3           4.6           1.5
# 4           5.0           1.4

# %%
y = df.drop(['sepal_length', 'petal_length'], axis = 1)
y.head()
# Out:
#    sepal_width  petal_width
# 0          3.5          0.2
# 1          3.0          0.2
# 2          3.2          0.2
# 3          3.1          0.2
# 4          3.6          0.2

# %%
ax = x.plot()
y.plot(figsize = (16,10), secondary_y=True, ax = ax)

# %%
x.plot(figsize=(10,5), x_compat = True)

# %%
df.plot(subplots = True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x1a1ec1ea58>,
# ...
#       dtype=object)

# %%
df.plot(subplots = True, sharex = False, layout = (2,3), figsize = (16,8))
plt.tight_layout()

# %%
from descartes import PolygonPatch

# %%
map_df = gpd.read_file("London_Borough_Excluding_MHW.shp")
# check data type so we can see that this is not a normal dataframe, but a GEOdataframe
map_df.head()
map_df.plot()

# %%
import geopandas as gpd

# %%
map_df
# Out:
#                       NAME   GSS_CODE   HECTARES  NONLD_AREA ONS_INNER  \
# 0     Kingston upon Thames  E09000021   3726.117       0.000         F
# 1                  Croydon  E09000008   8649.441       0.000         F
# 2                  Bromley  E09000006  15013.487       0.000         F
# 3                 Hounslow  E09000018   5658.541      60.755         F
# 4                   Ealing  E09000009   5554.428       0.000         F
# 5                 Havering  E09000016  11445.735     210.763         F
# 6               Hillingdon  E09000017  11570.063       0.000         F
# 7                   Harrow  E09000015   5046.330       0.000         F
# 8                    Brent  E09000005   4323.270       0.000         F
# 9                   Barnet  E09000003   8674.837       0.000         F
# 10                 Lambeth  E09000022   2724.940      43.927         T
# 11               Southwark  E09000028   2991.340     105.139         T
# ...
